# %% [markdown]
# ## Importing the Libraries and Packages

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.linear_model import LogisticRegression
sns.set(style="white", color_codes=True)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Importing the Dataset

# %%
iris=pd.read_csv("Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ## Plotting the Graph

# %%
sns.FacetGrid(iris, hue="Species",height=4).map(plt.scatter, "PetalLengthCm", "PetalWidthCm").add_legend()

# %%
sns.FacetGrid(iris, hue="Species",height=4).map(plt.scatter, "PetalLengthCm", "SepalLengthCm").add_legend()

# %%
sns.FacetGrid(iris, hue="Species",height=4).map(plt.scatter, "PetalLengthCm", "SepalWidthCm").add_legend()

# %%
sns.FacetGrid(iris, hue="Species",height=4).map(plt.scatter, "PetalWidthCm", "SepalLengthCm").add_legend()

# %%
sns.FacetGrid(iris, hue="Species",height=4).map(plt.scatter, "PetalWidthCm", "SepalWidthCm").add_legend()

# %%
sns.FacetGrid(iris, hue="Species",height=4).map(plt.scatter, "SepalLengthCm", "SepalWidthCm").add_legend()

# %%
X=iris[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].values
Y=iris[['Species']].values

# %%
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X,Y,test_size = 0.25, random_state = 123)

# %% [markdown]
# ## Model Training

# %%
LR=LogisticRegression()

# %%
LR.fit(X_Train,Y_Train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Model Testing

# %%
Prediction_lr = LR.predict(X_Test)
print("Accuracy of the model: ",LR.score(X_Test, Y_Test))
print("\nClassification Report: \n")
print(classification_report(Y_Test,Prediction_lr))
# Out:
# Accuracy of the model:  0.9736842105263158
#
# Classification Report:
#
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       0.89      1.00      0.94         8
#  Iris-virginica       1.00      0.93      0.96        14
#
#        accuracy                           0.97        38
#       macro avg       0.96      0.98      0.97        38
#    weighted avg       0.98      0.97      0.97        38

# %% [markdown]
# ## Plotting the Confusion Matrix

# %%
print("\n\nConfusion Matrix Plot : ")

cm = confusion_matrix(Y_Test, Prediction_lr, labels=LR.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=LR.classes_)
disp.plot()
plt.show()
# Out:
# Confusion Matrix Plot :
